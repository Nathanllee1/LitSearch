# %%
import pandas as pd

df = pd.read_csv('scrapeddata.csv')
df
# Out:
#       Boolean                                             Quotes  \
# 0           1  Thus far the history of my life presents nothi...
# 1           1  The idea struck me as a prudent one, though I ...
# 2           1  Though suspicions of Brown and Hamilton were n...
# 3           1  So we passed, hand-cuffed and in silence, thro...
# 4           1  My cup of sorrow was full to overflowing. Then...
# 5           1  He would make us hold up our heads, walk brisk...
# 6           1  The influences and associations that had alway...
# 7           1  He was my master, entitled by law to my flesh ...
# 8           1  I must toil day after day, endure abuse and ta...
# 9           1  Bent with excessive toil—actually suffering fo...
# 10          1  The existence of Slavery in its most cruel for...
# 11          1  Alas! Had it not been for my beloved violin, I...
# 12          1  No man who has never been placed in such a sit...
# ...

# %%
df = pd.DataFrame(df['Quotes'])
df.to_csv('xgboost.txt', sep='\t', index=False)
