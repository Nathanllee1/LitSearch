# %%
import pandas as pd

# %%
df = pd.read_csv('cleaneddata.csv')
df
# Out:
#        Unnamed: 0                                             Quotes   theme  \
# 0               0  Thus far the history of my life presents nothi...  family
# 1               4  My cup of sorrow was full to overflowing. Then...  family
# 2               6  The influences and associations that had alway...  family
# 3             152  Well, a favorable day for a person is a fortun...  family
# 4             153  . . . it’s very unusual to me, marrying the br...  family
# 5             177  Marie-Laure twists the chimney of the miniatur...  family
# 6             178  He sweeps her hair back from her ears; he swin...  family
# 7             184  “It’s not forever, Jutta. Two years, maybe. Ha...  family
# 8             185  “But I wasn’t trying to reach England. Or Pari...  family
# 9             191  Mostly he misses Jutta: her loyalty, her obsti...  family
# 10            196  “Marie-Laure,” he says without hesitation. He ...  family
# 11            200  He kisses her once on each cheek. “Until next ...  family
# 12            297   I signed up to protect this country. I do not...  family
# 13            299   When he reenlisted anyway, I thought, Okay. N...  family
# 14            359  Your son does not remember you, the div contin...  family
# 15            360  He wished he could love his new mother in the ...  family
# 16            361  All her life, Parwana had made sure to avoid s...  family
# 17            363  It’s true. Timur has embarrassed him. He has b...  family
# 18            364  Well, children are never everything you’d hope...  family
# 19            366  “You’ve made me proud, Markos.” I am fifty-fiv...  family
# 20            367  And so Baba’s little sister, Pari, was my secr...  family
# 21            368  People everywhere brag and whimper about the w...  family
# 22            373  I'm hungry but I'm afraid to go home till I fi...  family
# 23            374  I know when Dad does the bad thing. I know whe...  family
# 24            376  The three of us burst out laughing and Alphie ...  family
# 25            377  He's not coming, Mam. He doesn't care about us...  family
# 26            379  I can't tell her about Mam and Laman Griffin a...  family
# 27            383  Frieda tells the priest I had a bit of a dizzi...  family
# 28            405  All happy families are alike; each unhappy fam...  family
# 29            406  In that brief glance Vronsky had time to notic...  family
# ...           ...                                                ...     ...
# 11679        6943  "You're always half on Station Eleven," Pablo ...     art
# 11680        6949  I’ve been thinking about immortality lately. …...     art
# 11681        6951  “Well, it's nice that at least the celebrity g...     art
# 11682        7424   The Fox clapped his hands and sang, “Prettier...     art
# 11683        7425   Her beauty, which most of them had never seen...     art
# 11684        7426   And when the Brute is Ungit it lies with the ...     art
# 11685        7427   Since I write this book against the gods, it ...     art
# 11686        7429   And he took me... and pulled me right out of ...     art
# 11687        7430   For the world had broken in pieces and Psyche...     art
# 11688        7431   I must lie on the steps at the great gate of ...     art
# 11689        7432   Then I did a thing which I think few have don...     art
# 11690        7434   He made it to be as if, from the beginning, I...     art
# 11691        7437   For if the true story had been like their sto...     art
# 11692        7439   “Do not do it,” said the god. “You cannot esc...     art
# 11693        7440   But to steal her love from me! ...Do you thin...     art
# 11694        7441   The complaint was the answer. To have heard m...     art
# 11695        7489  Then beneath the colour there was the shape. S...     art
# 11696        7490  For always, [Mr. Bankes] thought, there was so...     art
# 11697        7493  [Lily] took shelter from the reverence which c...     art
# 11698        7495  It partook, [Mrs. Ramsay] felt, carefully help...     art
# 11699        7496  And then there it was, suddenly entire shaped ...     art
# 11700        7500  But what a power there was in the human soul! ...     art
# 11701        7501  [Lily] went on tunneling her way into her pict...     art
# 11702        7502  One wanted fifty pairs of eyes to see with, [L...     art
# 11703        7537  Iqbal stood up and looked all around. From the...     art
# 11704        7538  The northern horizon, which had turned a bluis...     art
# 11705        7539  Muslims sat and moped in their houses. Rumors ...     art
# 11706        7540  It was a dead cow with its belly bloated like ...     art
# 11707        7759  I can't tell if [Alice’s] actually real, or if...     art
# 11708        7767  Mom makes sculptures in the desert out of tras...     art
#
#        theme_in_quote
# 0                True
# 1                True
# 2                True
# 3                True
# 4                True
# 5                True
# 6                True
# 7                True
# 8                True
# 9                True
# 10               True
# 11               True
# 12               True
# 13               True
# 14               True
# 15               True
# 16               True
# 17               True
# 18               True
# 19               True
# 20               True
# 21               True
# 22               True
# 23               True
# 24               True
# 25               True
# 26               True
# 27               True
# 28               True
# 29               True
# ...               ...
# 11679            True
# 11680            True
# 11681            True
# 11682            True
# 11683            True
# 11684            True
# 11685            True
# 11686            True
# 11687            True
# 11688            True
# 11689            True
# 11690            True
# 11691            True
# 11692            True
# 11693            True
# 11694            True
# 11695            True
# 11696            True
# 11697            True
# 11698            True
# 11699            True
# 11700            True
# 11701            True
# 11702            True
# 11703            True
# 11704            True
# 11705            True
# 11706            True
# 11707            True
# 11708            True
#
# [11709 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

X = df['Quotes']
y = df['theme']

vectorizer = TfidfVectorizer(
    stop_words="english", 
    ngram_range=(1, 1),
    max_df=1.0,
    min_df=0.001
)
X = vectorizer.fit_transform(df["Quotes"])
y = vectorizer.fit_transform(df["theme"])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
                                                    random_state=0)

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.datasets import make_multilabel_classification

# %%
lda_model = LatentDirichletAllocation(n_topics=20,               # Number of topics
                                      max_iter=10,               # Max learning iterations
                                      learning_method='online',   
                                      random_state=100,          # Random state
                                      batch_size=128,            # n docs in each learning iter
                                      evaluate_every = -1,       # compute perplexity every n iters, default: Don't
                                      n_jobs = -1,               # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_vectorized)

print(lda_model)  # Model attributes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d9adcf0c686a> in <module>()
#       7                                       n_jobs = -1,               # Use all available CPUs
#       8                                      )
# ----> 9 lda_output = lda_model.fit_transform(data_vectorized)
#      10
#      11 print(lda_model)  # Model attributes
#
# NameError: name 'data_vectorized' is not defined
