# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('alldata.csv')

df
# Out:
#       Boolean                                               Data  \
# 0          no  ["fear-death-and-control", "uncertainty-and-au...
# 1          no  ["games-computers-and-virtual-reality", "leade...
# 2          no  ["interconnectedness", "compassion-and-selfish...
# 3          no  ["belonging-and-connection", "self-and-identit...
# 4          no  ["self-destruction", "character"]My cup of sor...
# 5          no  ["fear-of-the-other-and-internal-discord", "mo...
# 6          no  ["slavery-and-sexual-exploitation"]The influen...
# 7          no  ["left-tackle-protection-and-shifting-strategy...
# 8          no  ["religion-cynicism-and-hope"]I must toil day ...
# 9          no  ["racism-prejudice-and-the-american-west", "gr...
# 10         no  ["achievement-and-mortality", "storytelling", ...
# 11         no  ["belonging-and-connection", "safety-and-survi...
# 12         no  ["justice-revenge-and-god-s-will", "changes-of...
# ...

# %%
#select training vs test data
from sklearn.model_selection import train_test_split
'''
x = train['Cleaned']
y = train['Boolean']
'''
X_train, X_test, y_train, y_test = train_test_split(df['Cleaned'], df['Boolean'], test_size=0.33, random_state=42)

print('Number of quotes in the training data:', len(X_train))
print('Number of quotes in the test data:',len(X_test))

features = df.columns[:4]
features

datavectorizer = TfidfVectorizer(lowercase=True, strip_accents='ascii')
x = datavectorizer.fit_transform(x)
x = x.toarray()

booleanvectorizer = TfidfVectorizer()
y = booleanvectorizer.fit_transform(boolean)
y = y.toarray()
# Out:
# Number of quotes in the training data: 10990
# Number of quotes in the test data: 5414
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-877faf95edaa> in <module>()
#      14
#      15 datavectorizer = TfidfVectorizer(lowercase=True, strip_accents='ascii')
# ---> 16 x = datavectorizer.fit_transform(x)
#      17 x = x.toarray()
#      18
#
# NameError: name 'x' is not defined

# %%
clf = RandomForestClassifier()
clf.fit(x, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
from sklearn.metrics import confusion_matrix, classification_report

x = test['Cleaned']
x = datavectorizer.fit_transform(x)
x = x.toarray()


y = test['Boolean']
y = booleanvectorizer.fit_transform(boolean)
y = y.toarray()

test = clf.predict(x)
print(classification_report(y, x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-ee70dcb14133> in <module>()
#       7
#       8 y = test['Boolean']
# ----> 9 y = booleanvectorizer.fit_transform(boolean)
#      10 y = y.toarray()
#      11
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1379             Tf-idf-weighted document-term matrix.
#    1380         """
# -> 1381         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1382         self._tfidf.fit(X)
#    1383         # X is already a transformed view of raw_documents so
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#     867
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
# ...

# %%
#better
